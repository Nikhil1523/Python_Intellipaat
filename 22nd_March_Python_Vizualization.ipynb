# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil1523/Python_Intellipaat/blob/main/22nd_March_Python_Vizualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualization is the process of turning numbers and data into pictures, charts, graph so that it's easier to understand and analyze the patterns and trends in dataset.
#
# Benefits
# 1. Wide range of libraries
# 2. Customizability
# 3. Integrated with data analysis
# 4. Cost Effective
# 5. Ease of sharing
# 6. Large community support
#
# Disadvantages
# 1. Learning curve
# 2. Performance on large datasets
# 3. Complex Interactivity

# %%
# Matplotlib
# It is a popular python library used to create all kinds of charts and graphs
# 1. Easy to use
# 2. Wide variety of plots
# 3. Highly cutomizable
# 4. Integrate with other libraries

# %%
import matplotlib.pyplot as plt

# %%
# Line PLot
# Used to show trend over time
# Trend - Direction over a period of time
plt.figure(figsize = (8,5)) #sets the size if the graph (width, height)
month = ['January','February','March','April']
sales = [3000,2000,5000,4000]
expenses = [1000,5000,3000,4500]

#plt.plot(month,sales)

# Marker marks the datapoints and ms is for marker size, mfc is marker color, mec is for marker edge color
plt.plot(month,sales,marker='*',ms=15,mfc='red',mec='black',linestyle='-.',color='red',linewidth=5.5)
plt.plot(month,expenses,marker='s',ms=15,mfc='blue',mec='black',linestyle='-.',color='green',linewidth=5.5)
plt.xlabel('Month')
plt.ylabel('Sales and Expenses')
plt.title('Sales of First-Quarter')
plt.grid(axis = 'y')
plt.show()

# %%
# Bar Plots
categories = ['A','B','C']
values = [20,30,40]
plt.bar(categories,values,color='orange',width = 0.6)
plt.show()
#plt.barh() #for creating horizontal bars, height parameter can also be used just like width for normal bar
#plt.bar_label(plt.gca().containers[0])
# gca : fetching the current graph area

# %%
# Histogram
import numpy as np
x = np.random.randint(0, 1000, 56)
array = ([907, 822, 381, 239, 751, 234, 365, 263, 880, 417, 934, 242,  77,
       454, 659, 350, 332, 510, 278, 475,  57, 576, 365, 663, 167,  73,
       296, 776, 279,  28, 686, 855, 729, 139, 462, 204,  42, 140, 249,
       880, 779, 428, 757, 855, 107, 962,  10, 721, 354, 354, 433,   2,
       539, 426, 361, 998])
plt.hist(array, edgecolor ='white', bins = 10, color='purple')
plt.show()

# %%
x =[10,20,30,40,50,60,70,80,90,90,90,90,90,10,10,10,10,10]
x_sorted = sorted(set(x), key = x.count, reverse=True)
plt.hist(x_sorted, edgecolor ='black', bins =5, color='crimson')
# Out:
# (array([2., 2., 1., 2., 2.]),
#  array([10., 26., 42., 58., 74., 90.]),
#  <BarContainer object of 5 artists>)

# %%
# For sorting the data, although not needed normally for histograms as the distribution cannot be properly studied
plt.hist(sales,cumulative=True,edgecolor = 'black')
# Out:
# (array([1., 1., 1., 2., 2., 2., 3., 3., 3., 4.]),
#  array([2000., 2300., 2600., 2900., 3200., 3500., 3800., 4100., 4400.,
#         4700., 5000.]),
#  <BarContainer object of 10 artists>)

# %%
# scatter plot
# study hours and marks =  +ve relationship
# watching tv hrs increase and marks decrease  => -ve relation
# shoe size and intelligence = 0 or on relation

study_hr = [1,2,3,4,5]
marks = [50, 60, 80, 87, 90]

plt.scatter(study_hr, marks, color ='red')
plt.show()

# %%
# Pie Chart
# Show Proportion
a = [10,20,30,40]
labels = ['Mango','Apple','Kiwi','Dates']

plt.pie(a, labels = labels, autopct ='%.1f%%')
plt.show()

# %%
# Seaborn : a high level visualization library built on matplotlib, makes graphs look more attractive, easier to create
# and effective for statistical analysis.

import seaborn as sns
x = [10,20,30,40]
y = [20,30,40,50]
sns.lineplot(x=x,y=y)
plt.show()

# %%
x = ['Samsung','Vivo','Oppo']
y = [10000,25000,15000]
color = ['red','blue','green']
sns.barplot(x=x,y=y,palette=color)
plt.show()
# Out:
# /tmp/ipykernel_166/1553130471.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=y,palette=color)

# %%
age = [10,20,30,20,20,20,30,40,40,50,60,10,10]
sns.histplot(age, bins = 3)
plt.show()

# %%
sns.set_style('darkgrid')
temp = [10,20,30,40]
sales = [1000,2000,3000,4000]
sns.scatterplot(x=temp,y=sales)
plt.show()

# %%
# Area plot
import pandas as pd
data = pd.Series([10,20,30,40,50,60])
plt.plot(data)

# %%
data.plot(kind = 'area', color = 'yellow')
# Out:
# <Axes: >

# %%
plt.savefig('my_plot.png')
